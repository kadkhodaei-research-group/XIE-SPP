# %%
from utility.utility_general import *
from collections import Counter
# from predict_synthesis import *
import requests
from time import sleep
import tqdm
import crystals_tools
from IPython.display import display
from ase.formula import Formula
from ase.io import read as ase_read
from io import StringIO

from utility import util_tf

# %%
from pymatgen.ext.matproj import MPRester
api_key = "MCpqDZgh29W9r6X4Ru"

mpr: MPRester = MPRester(api_key)

def get_battery_data(self, formula_or_batt_id):
    """Returns batteries from a batt id or formula.

    Examples:
        get_battery("mp-300585433")
        get_battery("LiFePO4")
    """
    return self._make_request('/battery/%s' % formula_or_batt_id)

MPRester.get_battery_data = get_battery_data

# %%
data = mpr.get_data('V2O5')

# %%
# save_var(data, 'tmp/V2O5_raw_mp.pkl') 
data = load_var('tmp/V2O5_raw_mp.pkl') # 58 data points

# %%
print('Number of collected data: ', len(data))
# Out:
# Number of collected data:  58

# %%
experimentally_exists = ['mp-25279', 'mp-754670', 'mp-25288', 'mp-510568', 
                         'mp-1104615', 'mp-542844', 'mp-1178826', 'mp-624689']

# %%
df = pd.DataFrame({
    'query': data
})

for col in ['energy_per_atom', 'e_above_hull', 'material_id', 'full_formula']:
    df[col] = [i[col] for i in df['query']]
    
df['sgn'] = [i['spacegroup']['number'] for i in df['query']]
df['hall'] = [i['spacegroup']['hall'] for i in df['query']]
df['crystal_system'] = [i['spacegroup']['crystal_system'] for i in df['query']]
df['symbol'] = [i['spacegroup']['symbol'] for i in df['query']]

df['experiment'] = False
df.loc[df['material_id'].isin(experimentally_exists), 'experiment'] = True
df = df.sort_values('experiment', ascending=False)
df['atoms'] = [ase_read(StringIO(i['cif']), format='cif') for i in df['query']]

df
# Out:
#                                                 query  energy_per_atom  \
# 29  {'energy': -103.63725465, 'energy_per_atom': -...        -7.402661
# 51  {'energy': -208.02069668, 'energy_per_atom': -...        -7.429311
# 14  {'energy': -102.32647035, 'energy_per_atom': -...        -7.309034
# 46  {'energy': -103.3426698, 'energy_per_atom': -7...        -7.381619
# 47  {'energy': -51.20295963, 'energy_per_atom': -7...        -7.314709
# 1   {'energy': -104.06382799, 'energy_per_atom': -...        -7.433131
# 55  {'energy': -104.19153977, 'energy_per_atom': -...        -7.442253
# 56  {'energy': -103.77266521, 'energy_per_atom': -...        -7.412333
# 52  {'energy': -774.34388625, 'energy_per_atom': -...        -7.374704
# 40  {'energy': -764.45962847, 'energy_per_atom': -...        -7.280568
# 31  {'energy': -767.23723845, 'energy_per_atom': -...        -7.307021
# 32  {'energy': -207.4261955, 'energy_per_atom': -7...        -7.408078
# 33  {'energy': -767.56211316, 'energy_per_atom': -...        -7.310115
# 34  {'energy': -770.49797422, 'energy_per_atom': -...        -7.338076
# 35  {'energy': -767.64533933, 'energy_per_atom': -...        -7.310908
# 36  {'energy': -765.34878702, 'energy_per_atom': -...        -7.289036
# 37  {'energy': -767.03741743, 'energy_per_atom': -...        -7.305118
# 38  {'energy': -768.07335937, 'energy_per_atom': -...        -7.314984
# 39  {'energy': -104.03273672, 'energy_per_atom': -...        -7.430910
# 41  {'energy': -766.94048364, 'energy_per_atom': -...        -7.304195
# 53  {'energy': -766.41281623, 'energy_per_atom': -...        -7.299170
# 42  {'energy': -208.13222317, 'energy_per_atom': -...        -7.433294
# 43  {'energy': -770.11443017, 'energy_per_atom': -...        -7.334423
# 30  {'energy': -771.08940694, 'energy_per_atom': -...        -7.343709
# 45  {'energy': -208.27451109, 'energy_per_atom': -...        -7.438375
# 54  {'energy': -766.3571671, 'energy_per_atom': -7...        -7.298640
# 48  {'energy': -770.10767586, 'energy_per_atom': -...        -7.334359
# 49  {'energy': -770.39652192, 'energy_per_atom': -...        -7.337110
# 50  {'energy': -769.65810104, 'energy_per_atom': -...        -7.330077
# 44  {'energy': -208.07816084, 'energy_per_atom': -...        -7.431363
# 0   {'energy': -766.23984127, 'energy_per_atom': -...        -7.297522
# 28  {'energy': -768.23684279, 'energy_per_atom': -...        -7.316541
# 13  {'energy': -765.80390246, 'energy_per_atom': -...        -7.293370
# 2   {'energy': -771.98930997, 'energy_per_atom': -...        -7.352279
# 3   {'energy': -772.29533551, 'energy_per_atom': -...        -7.355194
# 4   {'energy': -770.16309963, 'energy_per_atom': -...        -7.334887
# 5   {'energy': -765.36492026, 'energy_per_atom': -...        -7.289190
# 6   {'energy': -765.81521452, 'energy_per_atom': -...        -7.293478
# 7   {'energy': -47.61625728, 'energy_per_atom': -6...        -6.802322
# 8   {'energy': -766.48838884, 'energy_per_atom': -...        -7.299889
# 9   {'energy': -767.24040089, 'energy_per_atom': -...        -7.307051
# 10  {'energy': -769.35515195, 'energy_per_atom': -...        -7.327192
# 11  {'energy': -155.66113011, 'energy_per_atom': -...        -7.412435
# 12  {'energy': -766.37401145, 'energy_per_atom': -...        -7.298800
# 15  {'energy': -767.13285847, 'energy_per_atom': -...        -7.306027
# 27  {'energy': -767.89882891, 'energy_per_atom': -...        -7.313322
# 16  {'energy': -767.31500025, 'energy_per_atom': -...        -7.307762
# 17  {'energy': -766.50890889, 'energy_per_atom': -...        -7.300085
# 18  {'energy': -726.79570795, 'energy_per_atom': -...        -7.416283
# 19  {'energy': -769.04107216, 'energy_per_atom': -...        -7.324201
# 20  {'energy': -770.08408876, 'energy_per_atom': -...        -7.334134
# 21  {'energy': -770.45576538, 'energy_per_atom': -...        -7.337674
# 22  {'energy': -770.11456658, 'energy_per_atom': -...        -7.334424
# 23  {'energy': -768.59551985, 'energy_per_atom': -...        -7.319957
# 24  {'energy': -767.92666028, 'energy_per_atom': -...        -7.313587
# 25  {'energy': -769.38285758, 'energy_per_atom': -...        -7.327456
# 26  {'energy': -103.40814579, 'energy_per_atom': -...        -7.386296
# 57  {'energy': -104.02091391, 'energy_per_atom': -...        -7.430065
#
#     e_above_hull material_id full_formula  sgn          hall crystal_system  \
# 29      0.039592  mp-1104615        V4O10    2          -P 1      triclinic
# 51      0.012942    mp-25288        V8O20   62     -P 2ac 2n   orthorhombic
# 14      0.133219   mp-624689        V4O10   59  P 2 2ab -1ab   orthorhombic
# 46      0.060634   mp-542844        V4O10   15        -C 2yc     monoclinic
# 47      0.127544  mp-1178826         V2O5   12         -C 2y     monoclinic
# 1       0.009122   mp-754670        V4O10   59  P 2 2ab -1ab   orthorhombic
# 55      0.000000    mp-25279        V4O10   59  P 2 2ab -1ab   orthorhombic
# 56      0.029920   mp-510568        V4O10   11        -P 2yb     monoclinic
# 52      0.067549  mp-1245120       V30O75    1           P 1      triclinic
# 40      0.537399  mp-1245283       V30O75    1           P 1      triclinic
# 31      0.510946  mp-1245171       V30O75    1           P 1      triclinic
# 32      0.034174   mp-776041        V8O20   14       -P 2ybc     monoclinic
# 33      0.507852  mp-1245096       V30O75    1           P 1      triclinic
# 34      0.479891  mp-1245221       V30O75    1           P 1      triclinic
# 35      0.507059  mp-1245240       V30O75    1           P 1      triclinic
# 36      0.528931  mp-1245061       V30O75    1           P 1      triclinic
# 37      0.512849  mp-1245058       V30O75    1           P 1      triclinic
# 38      0.502983  mp-1245284       V30O75    1           P 1      triclinic
# 39      0.011343    mp-25233        V4O10   63       -C 2c 2   orthorhombic
# 41      0.513772  mp-1244961       V30O75    1           P 1      triclinic
# 53      0.518797  mp-1245198       V30O75    1           P 1      triclinic
# 42      0.008959    mp-25280        V8O20   62     -P 2ac 2n   orthorhombic
# 43      0.483544  mp-1245160       V30O75    1           P 1      triclinic
# 30      0.474258  mp-1245315       V30O75    1           P 1      triclinic
# 45      0.003877   mp-776152        V8O20   62     -P 2ac 2n   orthorhombic
# 54      0.519327  mp-1244942       V30O75    1           P 1      triclinic
# 48      0.483608  mp-1244904       V30O75    1           P 1      triclinic
# 49      0.480857  mp-1244920       V30O75    1           P 1      triclinic
# 50      0.487890  mp-1245174       V30O75    1           P 1      triclinic
# 44      0.010890   mp-755235        V8O20   62     -P 2ac 2n   orthorhombic
# 0       0.520445  mp-1245272       V30O75    1           P 1      triclinic
# 28      0.125711  mp-1245219       V30O75    1           P 1      triclinic
# 13      0.524597  mp-1244985       V30O75    1           P 1      triclinic
# 2       0.089974  mp-1245156       V30O75    1           P 1      triclinic
# 3       0.087059  mp-1245162       V30O75    1           P 1      triclinic
# 4       0.483080  mp-1245101       V30O75    1           P 1      triclinic
# 5       0.528777  mp-1244901       V30O75    1           P 1      triclinic
# 6       0.524489  mp-1245040       V30O75    1           P 1      triclinic
# 7       0.639930  mp-1216596         V2O5   71        -I 2 2   orthorhombic
# 8       0.518078  mp-1245153       V30O75    1           P 1      triclinic
# 9       0.510916  mp-1244978       V30O75    1           P 1      triclinic
# 10      0.490775  mp-1245097       V30O75    1           P 1      triclinic
# 11      0.029818    mp-25207        V6O15   12         -C 2y     monoclinic
# 12      0.519167  mp-1245118       V30O75    1           P 1      triclinic
# 15      0.511940  mp-1245325       V30O75    1           P 1      triclinic
# 27      0.504645  mp-1245142       V30O75    1           P 1      triclinic
# 16      0.510205  mp-1245005       V30O75    1           P 1      triclinic
# 17      0.517882  mp-1245312       V30O75    1           P 1      triclinic
# 18      0.025970   mp-849565       V28O70   13        -P 2yc     monoclinic
# 19      0.118052  mp-1244996       V30O75    1           P 1      triclinic
# 20      0.108119  mp-1244889       V30O75    1           P 1      triclinic
# 21      0.104579  mp-1245000       V30O75    1           P 1      triclinic
# 22      0.107828  mp-1245137       V30O75    1           P 1      triclinic
# 23      0.498010  mp-1244925       V30O75    1           P 1      triclinic
# 24      0.504380  mp-1245049       V30O75    1           P 1      triclinic
# 25      0.490511  mp-1245275       V30O75    1           P 1      triclinic
# 26      0.055957   mvc-11086        V4O10   55      -P 2 2ab   orthorhombic
# 57      0.012188   mp-754585        V4O10   43       F 2 -2d   orthorhombic
#
#     symbol  experiment                                              atoms
# 29     P-1        True  (Atom('V', [2.8973492269345766, 5.333355758664...
# 51    Pnma        True  (Atom('V', [2.7144735, 8.907559839399, 10.1779...
# 14    Pmmn        True  (Atom('V', [1.4421545, 3.735567159696, 1.78359...
# 46    C2/c        True  (Atom('V', [7.656589140310443, 4.3194922300652...
# 47    C2/m        True  (Atom('V', [1.9628695893368011, 0.496278715538...
# 1     Pmmn        True  (Atom('V', [0.0, 0.531171342919, 1.70007574128...
# 55    Pmmn        True  (Atom('V', [0.0, 2.9346624387689997, 7.5026582...
# 56  P2_1/m        True  (Atom('V', [2.7107849999999996, 5.174873298553...
# 52      P1       False  (Atom('V', [12.919200685363656, 11.44055405050...
# 40      P1       False  (Atom('V', [0.6849783562529564, 0.199785116458...
# 31      P1       False  (Atom('V', [0.4812499276774406, 10.05357817187...
# 32  P2_1/c       False  (Atom('V', [2.697859533831, 2.349800525614698,...
# 33      P1       False  (Atom('V', [11.884506329833373, 0.222856573245...
# 34      P1       False  (Atom('V', [1.4579806681878957, 10.18090822690...
# 35      P1       False  (Atom('V', [7.78546781203443, 1.74808592642574...
# 36      P1       False  (Atom('V', [2.223640709682425, 9.4002667048340...
# 37      P1       False  (Atom('V', [13.688301946237821, 5.834487735746...
# 38      P1       False  (Atom('V', [12.392528050010867, 0.504586773724...
# 39    Cmcm       False  (Atom('V', [2.677119225262332, 1.0102236542834...
# 41      P1       False  (Atom('V', [12.37460875203841, 4.2143834753262...
# 53      P1       False  (Atom('V', [6.73172598607967, 11.1181652294575...
# 42    Pnma       False  (Atom('V', [1.2465021947580002, 2.899358550218...
# 43      P1       False  (Atom('V', [1.1418235419384422, 6.500387684094...
# 30      P1       False  (Atom('V', [-0.300923530766949, 4.925784182804...
# 45    Pnma       False  (Atom('V', [1.6528165, 5.621423355308, 1.34681...
# 54      P1       False  (Atom('V', [10.34392165223903, 0.3743852564257...
# 48      P1       False  (Atom('V', [10.385809396973515, 1.306627344338...
# 49      P1       False  (Atom('V', [9.76749085578568, 11.1958329744488...
# 50      P1       False  (Atom('V', [0.7959508818949154, 5.582530405625...
# 44    Pnma       False  (Atom('V', [1.47935625, 7.181025906495998, 9.1...
# 0       P1       False  (Atom('V', [12.271691164324231, 4.585031592898...
# 28      P1       False  (Atom('V', [6.879390702301856, 11.514683404948...
# 13      P1       False  (Atom('V', [12.080149575523969, 5.334980954028...
# 2       P1       False  (Atom('V', [7.265456234364012, 10.215569103299...
# 3       P1       False  (Atom('V', [5.901362016368758, 9.4293624275955...
# 4       P1       False  (Atom('V', [2.6890155612685738, 11.29921381295...
# 5       P1       False  (Atom('V', [8.695333668083766, 8.1608238715453...
# 6       P1       False  (Atom('V', [10.047937903055304, 0.026665087273...
# 7     Immm       False  (Atom('V', [13.22490863852492, 4.0724814092808...
# 8       P1       False  (Atom('V', [11.630060405015882, 10.12285885392...
# 9       P1       False  (Atom('V', [10.460430082788566, 9.714044338224...
# 10      P1       False  (Atom('V', [8.589154564958006, 10.635808855172...
# 11    C2/m       False  (Atom('V', [15.457967702623002, 3.598877489740...
# 12      P1       False  (Atom('V', [8.657898035015918, 0.2435606410833...
# 15      P1       False  (Atom('V', [9.639578142668224, 1.3310135362005...
# 27      P1       False  (Atom('V', [1.1487655569638207, 11.78797192451...
# 16      P1       False  (Atom('V', [8.197820909379569, 12.133424578128...
# 17      P1       False  (Atom('V', [9.718634878436783, 11.593589858853...
# 18    P2/c       False  (Atom('V', [0.36363533112199997, 18.7039874484...
# 19      P1       False  (Atom('V', [12.880096777980901, 11.70469622370...
# 20      P1       False  (Atom('V', [0.7962448665768325, 6.467369806656...
# 21      P1       False  (Atom('V', [10.520922339405066, 5.325442653504...
# 22      P1       False  (Atom('V', [12.514903869985599, 4.776164537769...
# 23      P1       False  (Atom('V', [11.833517638555145, 7.554289259738...
# 24      P1       False  (Atom('V', [0.05965471507297885, 12.0208070457...
# 25      P1       False  (Atom('V', [10.60539175176568, 6.5542997361615...
# 26    Pbam       False  (Atom('V', [0.0, 4.026658159788, 3.98137511814...
# 57    Fdd2       False  (Atom('V', [17.581988264832738, 3.589346972476...

# %%
print('Number of duplicates:', len(df[df.duplicated(['symbol', 'full_formula'])]))
# Out:
# Number of duplicates: 44

# %% [markdown]
# # Evaluations

# %% [markdown]
# ## CAE+MLP

# %%
import tensorflow as tf
util_tf.tf_select_gpu(0)
# Out:
# Total Num. GPUs Available:  6
# 6 Physical GPUs, 1 Logical GPU
#
# Selected resources:
# /physical_device:CPU:0
# /physical_device:GPU:0

# %%
from tensorflow.keras.models import load_model
import config
import image_generator

encoder = load_model(config.cae_mlp_model_dir + '/encoder.h5')
encoder.load_weights(config.cae_mlp_model_dir + '/encoder_weights.h5')

generator = image_generator.ImageGeneratorDataFrame(df[['atoms']], target_col='atoms')
with tf.device('/device:GPU:0'):
    lsr = encoder.predict(
        generator, 
        steps=len(generator),
        verbose=1,
#         use_multiprocessing=True,
#         workers=32,
#         max_queue_size=10,
                                 )

clf = load_var(config.cae_mlp_model_clf_dir + '/classifier_class.pkl')
yp = clf.predict_proba(lsr)
df['yp cae-mlp'] = yp.flatten()
df['ypl cae-mlp'] = np.sign(np.sign(yp.flatten() - 0.5) + .5)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - 12s 106ms/step

# %% [markdown]
# ## CNN

# %%
from keras.models import load_model
import config

cnn_model = load_model(config.cnn_model_dir + '/model.h5')
cnn_model.load_weights(config.cnn_model_dir + '/weights0006.h5')


generator = image_generator.ImageGeneratorDataFrame(df[['atoms']], target_col='atoms')
yp = cnn_model.predict(
    generator, 
    steps=len(generator),
    verbose=1,
#     use_multiprocessing=True,
#     workers=32,
#     max_queue_size=10,
                             )
df['yp cnn'] = yp.flatten()
df['ypl cnn'] = np.sign(np.sign(yp.flatten() - 0.5) + .5)
# Out:
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 57/58 [============================>.] - ETA: 0sWARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 58/58 [==============================] - 14s 177ms/step

# %%
df.to_pickle('tmp/V2O5.pkl')

# %%
df = pd.read_pickle('tmp/V2O5.pkl')
# Out:
#                                                 query  energy_per_atom  \
# 29  {'energy': -103.63725465, 'energy_per_atom': -...        -7.402661
# 51  {'energy': -208.02069668, 'energy_per_atom': -...        -7.429311
# 14  {'energy': -102.32647035, 'energy_per_atom': -...        -7.309034
# 46  {'energy': -103.3426698, 'energy_per_atom': -7...        -7.381619
# 47  {'energy': -51.20295963, 'energy_per_atom': -7...        -7.314709
# 1   {'energy': -104.06382799, 'energy_per_atom': -...        -7.433131
# 55  {'energy': -104.19153977, 'energy_per_atom': -...        -7.442253
# 56  {'energy': -103.77266521, 'energy_per_atom': -...        -7.412333
# 52  {'energy': -774.34388625, 'energy_per_atom': -...        -7.374704
# 40  {'energy': -764.45962847, 'energy_per_atom': -...        -7.280568
# 31  {'energy': -767.23723845, 'energy_per_atom': -...        -7.307021
# 32  {'energy': -207.4261955, 'energy_per_atom': -7...        -7.408078
# 33  {'energy': -767.56211316, 'energy_per_atom': -...        -7.310115
# 34  {'energy': -770.49797422, 'energy_per_atom': -...        -7.338076
# 35  {'energy': -767.64533933, 'energy_per_atom': -...        -7.310908
# 36  {'energy': -765.34878702, 'energy_per_atom': -...        -7.289036
# 37  {'energy': -767.03741743, 'energy_per_atom': -...        -7.305118
# 38  {'energy': -768.07335937, 'energy_per_atom': -...        -7.314984
# 39  {'energy': -104.03273672, 'energy_per_atom': -...        -7.430910
# 41  {'energy': -766.94048364, 'energy_per_atom': -...        -7.304195
# 53  {'energy': -766.41281623, 'energy_per_atom': -...        -7.299170
# 42  {'energy': -208.13222317, 'energy_per_atom': -...        -7.433294
# 43  {'energy': -770.11443017, 'energy_per_atom': -...        -7.334423
# 30  {'energy': -771.08940694, 'energy_per_atom': -...        -7.343709
# 45  {'energy': -208.27451109, 'energy_per_atom': -...        -7.438375
# 54  {'energy': -766.3571671, 'energy_per_atom': -7...        -7.298640
# 48  {'energy': -770.10767586, 'energy_per_atom': -...        -7.334359
# 49  {'energy': -770.39652192, 'energy_per_atom': -...        -7.337110
# 50  {'energy': -769.65810104, 'energy_per_atom': -...        -7.330077
# 44  {'energy': -208.07816084, 'energy_per_atom': -...        -7.431363
# 0   {'energy': -766.23984127, 'energy_per_atom': -...        -7.297522
# 28  {'energy': -768.23684279, 'energy_per_atom': -...        -7.316541
# 13  {'energy': -765.80390246, 'energy_per_atom': -...        -7.293370
# 2   {'energy': -771.98930997, 'energy_per_atom': -...        -7.352279
# 3   {'energy': -772.29533551, 'energy_per_atom': -...        -7.355194
# 4   {'energy': -770.16309963, 'energy_per_atom': -...        -7.334887
# 5   {'energy': -765.36492026, 'energy_per_atom': -...        -7.289190
# 6   {'energy': -765.81521452, 'energy_per_atom': -...        -7.293478
# 7   {'energy': -47.61625728, 'energy_per_atom': -6...        -6.802322
# 8   {'energy': -766.48838884, 'energy_per_atom': -...        -7.299889
# 9   {'energy': -767.24040089, 'energy_per_atom': -...        -7.307051
# 10  {'energy': -769.35515195, 'energy_per_atom': -...        -7.327192
# 11  {'energy': -155.66113011, 'energy_per_atom': -...        -7.412435
# 12  {'energy': -766.37401145, 'energy_per_atom': -...        -7.298800
# 15  {'energy': -767.13285847, 'energy_per_atom': -...        -7.306027
# 27  {'energy': -767.89882891, 'energy_per_atom': -...        -7.313322
# 16  {'energy': -767.31500025, 'energy_per_atom': -...        -7.307762
# 17  {'energy': -766.50890889, 'energy_per_atom': -...        -7.300085
# 18  {'energy': -726.79570795, 'energy_per_atom': -...        -7.416283
# 19  {'energy': -769.04107216, 'energy_per_atom': -...        -7.324201
# 20  {'energy': -770.08408876, 'energy_per_atom': -...        -7.334134
# 21  {'energy': -770.45576538, 'energy_per_atom': -...        -7.337674
# 22  {'energy': -770.11456658, 'energy_per_atom': -...        -7.334424
# 23  {'energy': -768.59551985, 'energy_per_atom': -...        -7.319957
# 24  {'energy': -767.92666028, 'energy_per_atom': -...        -7.313587
# 25  {'energy': -769.38285758, 'energy_per_atom': -...        -7.327456
# 26  {'energy': -103.40814579, 'energy_per_atom': -...        -7.386296
# 57  {'energy': -104.02091391, 'energy_per_atom': -...        -7.430065
#
#     e_above_hull material_id full_formula  sgn          hall crystal_system  \
# 29      0.039592  mp-1104615        V4O10    2          -P 1      triclinic
# 51      0.012942    mp-25288        V8O20   62     -P 2ac 2n   orthorhombic
# 14      0.133219   mp-624689        V4O10   59  P 2 2ab -1ab   orthorhombic
# 46      0.060634   mp-542844        V4O10   15        -C 2yc     monoclinic
# 47      0.127544  mp-1178826         V2O5   12         -C 2y     monoclinic
# 1       0.009122   mp-754670        V4O10   59  P 2 2ab -1ab   orthorhombic
# 55      0.000000    mp-25279        V4O10   59  P 2 2ab -1ab   orthorhombic
# 56      0.029920   mp-510568        V4O10   11        -P 2yb     monoclinic
# 52      0.067549  mp-1245120       V30O75    1           P 1      triclinic
# 40      0.537399  mp-1245283       V30O75    1           P 1      triclinic
# 31      0.510946  mp-1245171       V30O75    1           P 1      triclinic
# 32      0.034174   mp-776041        V8O20   14       -P 2ybc     monoclinic
# 33      0.507852  mp-1245096       V30O75    1           P 1      triclinic
# 34      0.479891  mp-1245221       V30O75    1           P 1      triclinic
# 35      0.507059  mp-1245240       V30O75    1           P 1      triclinic
# 36      0.528931  mp-1245061       V30O75    1           P 1      triclinic
# 37      0.512849  mp-1245058       V30O75    1           P 1      triclinic
# 38      0.502983  mp-1245284       V30O75    1           P 1      triclinic
# 39      0.011343    mp-25233        V4O10   63       -C 2c 2   orthorhombic
# 41      0.513772  mp-1244961       V30O75    1           P 1      triclinic
# 53      0.518797  mp-1245198       V30O75    1           P 1      triclinic
# 42      0.008959    mp-25280        V8O20   62     -P 2ac 2n   orthorhombic
# 43      0.483544  mp-1245160       V30O75    1           P 1      triclinic
# 30      0.474258  mp-1245315       V30O75    1           P 1      triclinic
# 45      0.003877   mp-776152        V8O20   62     -P 2ac 2n   orthorhombic
# 54      0.519327  mp-1244942       V30O75    1           P 1      triclinic
# 48      0.483608  mp-1244904       V30O75    1           P 1      triclinic
# 49      0.480857  mp-1244920       V30O75    1           P 1      triclinic
# 50      0.487890  mp-1245174       V30O75    1           P 1      triclinic
# 44      0.010890   mp-755235        V8O20   62     -P 2ac 2n   orthorhombic
# 0       0.520445  mp-1245272       V30O75    1           P 1      triclinic
# 28      0.125711  mp-1245219       V30O75    1           P 1      triclinic
# 13      0.524597  mp-1244985       V30O75    1           P 1      triclinic
# 2       0.089974  mp-1245156       V30O75    1           P 1      triclinic
# 3       0.087059  mp-1245162       V30O75    1           P 1      triclinic
# 4       0.483080  mp-1245101       V30O75    1           P 1      triclinic
# 5       0.528777  mp-1244901       V30O75    1           P 1      triclinic
# 6       0.524489  mp-1245040       V30O75    1           P 1      triclinic
# 7       0.639930  mp-1216596         V2O5   71        -I 2 2   orthorhombic
# 8       0.518078  mp-1245153       V30O75    1           P 1      triclinic
# 9       0.510916  mp-1244978       V30O75    1           P 1      triclinic
# 10      0.490775  mp-1245097       V30O75    1           P 1      triclinic
# 11      0.029818    mp-25207        V6O15   12         -C 2y     monoclinic
# 12      0.519167  mp-1245118       V30O75    1           P 1      triclinic
# 15      0.511940  mp-1245325       V30O75    1           P 1      triclinic
# 27      0.504645  mp-1245142       V30O75    1           P 1      triclinic
# 16      0.510205  mp-1245005       V30O75    1           P 1      triclinic
# 17      0.517882  mp-1245312       V30O75    1           P 1      triclinic
# 18      0.025970   mp-849565       V28O70   13        -P 2yc     monoclinic
# 19      0.118052  mp-1244996       V30O75    1           P 1      triclinic
# 20      0.108119  mp-1244889       V30O75    1           P 1      triclinic
# 21      0.104579  mp-1245000       V30O75    1           P 1      triclinic
# 22      0.107828  mp-1245137       V30O75    1           P 1      triclinic
# 23      0.498010  mp-1244925       V30O75    1           P 1      triclinic
# 24      0.504380  mp-1245049       V30O75    1           P 1      triclinic
# 25      0.490511  mp-1245275       V30O75    1           P 1      triclinic
# 26      0.055957   mvc-11086        V4O10   55      -P 2 2ab   orthorhombic
# 57      0.012188   mp-754585        V4O10   43       F 2 -2d   orthorhombic
#
#     symbol  experiment                                              atoms  \
# 29     P-1        True  (Atom('V', [2.8973492269345766, 5.333355758664...
# 51    Pnma        True  (Atom('V', [2.7144735, 8.907559839399, 10.1779...
# 14    Pmmn        True  (Atom('V', [1.4421545, 3.735567159696, 1.78359...
# 46    C2/c        True  (Atom('V', [7.656589140310443, 4.3194922300652...
# 47    C2/m        True  (Atom('V', [1.9628695893368011, 0.496278715538...
# 1     Pmmn        True  (Atom('V', [0.0, 0.531171342919, 1.70007574128...
# 55    Pmmn        True  (Atom('V', [0.0, 2.9346624387689997, 7.5026582...
# 56  P2_1/m        True  (Atom('V', [2.7107849999999996, 5.174873298553...
# 52      P1       False  (Atom('V', [12.919200685363656, 11.44055405050...
# 40      P1       False  (Atom('V', [0.6849783562529564, 0.199785116458...
# 31      P1       False  (Atom('V', [0.4812499276774406, 10.05357817187...
# 32  P2_1/c       False  (Atom('V', [2.697859533831, 2.349800525614698,...
# 33      P1       False  (Atom('V', [11.884506329833373, 0.222856573245...
# 34      P1       False  (Atom('V', [1.4579806681878957, 10.18090822690...
# 35      P1       False  (Atom('V', [7.78546781203443, 1.74808592642574...
# 36      P1       False  (Atom('V', [2.223640709682425, 9.4002667048340...
# 37      P1       False  (Atom('V', [13.688301946237821, 5.834487735746...
# 38      P1       False  (Atom('V', [12.392528050010867, 0.504586773724...
# 39    Cmcm       False  (Atom('V', [2.677119225262332, 1.0102236542834...
# 41      P1       False  (Atom('V', [12.37460875203841, 4.2143834753262...
# 53      P1       False  (Atom('V', [6.73172598607967, 11.1181652294575...
# 42    Pnma       False  (Atom('V', [1.2465021947580002, 2.899358550218...
# 43      P1       False  (Atom('V', [1.1418235419384422, 6.500387684094...
# 30      P1       False  (Atom('V', [-0.300923530766949, 4.925784182804...
# 45    Pnma       False  (Atom('V', [1.6528165, 5.621423355308, 1.34681...
# 54      P1       False  (Atom('V', [10.34392165223903, 0.3743852564257...
# 48      P1       False  (Atom('V', [10.385809396973515, 1.306627344338...
# 49      P1       False  (Atom('V', [9.76749085578568, 11.1958329744488...
# 50      P1       False  (Atom('V', [0.7959508818949154, 5.582530405625...
# 44    Pnma       False  (Atom('V', [1.47935625, 7.181025906495998, 9.1...
# 0       P1       False  (Atom('V', [12.271691164324231, 4.585031592898...
# 28      P1       False  (Atom('V', [6.879390702301856, 11.514683404948...
# 13      P1       False  (Atom('V', [12.080149575523969, 5.334980954028...
# 2       P1       False  (Atom('V', [7.265456234364012, 10.215569103299...
# 3       P1       False  (Atom('V', [5.901362016368758, 9.4293624275955...
# 4       P1       False  (Atom('V', [2.6890155612685738, 11.29921381295...
# 5       P1       False  (Atom('V', [8.695333668083766, 8.1608238715453...
# 6       P1       False  (Atom('V', [10.047937903055304, 0.026665087273...
# 7     Immm       False  (Atom('V', [13.22490863852492, 4.0724814092808...
# 8       P1       False  (Atom('V', [11.630060405015882, 10.12285885392...
# 9       P1       False  (Atom('V', [10.460430082788566, 9.714044338224...
# 10      P1       False  (Atom('V', [8.589154564958006, 10.635808855172...
# 11    C2/m       False  (Atom('V', [15.457967702623002, 3.598877489740...
# 12      P1       False  (Atom('V', [8.657898035015918, 0.2435606410833...
# 15      P1       False  (Atom('V', [9.639578142668224, 1.3310135362005...
# 27      P1       False  (Atom('V', [1.1487655569638207, 11.78797192451...
# 16      P1       False  (Atom('V', [8.197820909379569, 12.133424578128...
# 17      P1       False  (Atom('V', [9.718634878436783, 11.593589858853...
# 18    P2/c       False  (Atom('V', [0.36363533112199997, 18.7039874484...
# 19      P1       False  (Atom('V', [12.880096777980901, 11.70469622370...
# 20      P1       False  (Atom('V', [0.7962448665768325, 6.467369806656...
# 21      P1       False  (Atom('V', [10.520922339405066, 5.325442653504...
# 22      P1       False  (Atom('V', [12.514903869985599, 4.776164537769...
# 23      P1       False  (Atom('V', [11.833517638555145, 7.554289259738...
# 24      P1       False  (Atom('V', [0.05965471507297885, 12.0208070457...
# 25      P1       False  (Atom('V', [10.60539175176568, 6.5542997361615...
# 26    Pbam       False  (Atom('V', [0.0, 4.026658159788, 3.98137511814...
# 57    Fdd2       False  (Atom('V', [17.581988264832738, 3.589346972476...
#
#     yp cae-mlp  ypl cae-mlp    yp cnn  ypl cnn
# 29    0.999997          1.0  0.999844      1.0
# 51    0.998370          1.0  0.998334      1.0
# 14    0.999700          1.0  0.978988      1.0
# 46    0.408365         -1.0  0.314881     -1.0
# 47    0.998105          1.0  0.778465      1.0
# 1     0.990838          1.0  0.999984      1.0
# 55    0.999971          1.0  0.999839      1.0
# 56    0.524704          1.0  0.947620      1.0
# 52    0.999988          1.0  0.999726      1.0
# 40    1.000000          1.0  0.999795      1.0
# 31    0.999997          1.0  0.999967      1.0
# 32    0.999985          1.0  0.999232      1.0
# 33    0.999960          1.0  0.999156      1.0
# 34    1.000000          1.0  0.999961      1.0
# 35    1.000000          1.0  0.999955      1.0
# 36    0.999997          1.0  0.999876      1.0
# 37    1.000000          1.0  0.999918      1.0
# 38    0.999986          1.0  0.999820      1.0
# 39    0.999914          1.0  0.998887      1.0
# 41    0.999999          1.0  0.999940      1.0
# 53    0.999999          1.0  0.999931      1.0
# 42    0.999770          1.0  0.998907      1.0
# 43    0.999982          1.0  0.999706      1.0
# 30    0.999988          1.0  0.999909      1.0
# 45    0.115467         -1.0  0.951849      1.0
# 54    0.999990          1.0  0.999923      1.0
# 48    0.999828          1.0  0.999902      1.0
# 49    0.999999          1.0  0.999882      1.0
# 50    0.999923          1.0  0.999613      1.0
# 44    0.911845          1.0  0.999780      1.0
# 0     0.999996          1.0  0.999857      1.0
# 28    0.999914          1.0  0.993724      1.0
# 13    1.000000          1.0  0.999917      1.0
# 2     0.990335          1.0  0.997647      1.0
# 3     0.999836          1.0  0.999721      1.0
# 4     1.000000          1.0  0.999890      1.0
# 5     0.999978          1.0  0.999543      1.0
# 6     0.999993          1.0  0.999915      1.0
# 7     0.999958          1.0  0.999992      1.0
# 8     0.999996          1.0  0.999853      1.0
# 9     0.999999          1.0  0.999948      1.0
# 10    1.000000          1.0  0.999922      1.0
# 11    0.998458          1.0  0.996718      1.0
# 12    1.000000          1.0  0.999939      1.0
# 15    0.999998          1.0  0.999732      1.0
# 27    1.000000          1.0  0.999913      1.0
# 16    0.999978          1.0  0.999922      1.0
# 17    0.999997          1.0  0.999890      1.0
# 18    0.747744          1.0  0.997620      1.0
# 19    0.999998          1.0  0.999975      1.0
# 20    0.999999          1.0  0.999531      1.0
# 21    0.999999          1.0  0.999934      1.0
# 22    0.999998          1.0  0.999794      1.0
# 23    0.999997          1.0  0.999924      1.0
# 24    0.999997          1.0  0.999941      1.0
# 25    0.999989          1.0  0.999953      1.0
# 26    0.957127          1.0  0.996945      1.0
# 57    0.999996          1.0  0.999971      1.0
